# %%
import os
import re

# %%
os.getcwd()
# Out:
# 'C:\\Users\\wrhodges1986\\Desktop\\BYU'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'BYU Software Engineer.ipynb', 'frankenstein.txt']

# %%
f = open('frankenstein.txt', encoding='utf-8')

# %%
contents = f.read()

# %%
parsed_file = re.findall(r"[-\w']+", contents)

# %%
words = {}

# %%
for word in parsed_file:
    if word not in words:
        words[word] = 1
    else:
        words[word] += 1

# %%
words
# Out:
# {'Project': 83,
#  "Gutenberg's": 1,
#  'Frankenstein': 30,
#  'by': 470,
#  'Mary': 4,
#  'Wollstonecraft': 4,
#  'Godwin': 4,
#  'Shelley': 4,
#  'This': 81,
#  'eBook': 6,
#  'is': 328,
#  'for': 494,
#  'the': 4069,
#  'use': 17,
#  'of': 2745,
#  'anyone': 9,
#  'anywhere': 2,
#  'at': 305,
#  'no': 156,
#  'cost': 3,
#  'and': 3006,
#  'with': 705,
#  'almost': 39,
#  'restrictions': 2,
#  'whatsoever': 3,
#  'You': 87,
#  'may': 108,
#  'copy': 12,
#  'it': 461,
#  'give': 23,
#  'away': 52,
#  'or': 247,
#  're-use': 2,
#  'under': 29,
#  'terms': 27,
#  'Gutenberg': 26,
#  'License': 10,
#  'included': 4,
#  'this': 363,
#  'online': 4,
#  'www': 6,
#  'gutenberg': 6,
#  'net': 5,
#  'Title': 1,
#  'The': 297,
#  'Modern': 2,
#  'Prometheus': 2,
#  'Author': 1,
#  'Release': 1,
#  'Date': 1,
#  'June': 2,
#  '17': 13,
#  '2008': 1,
#  'EBook': 2,
#  '84': 2,
#  'Last': 3,
#  'updated': 1,
#  'January': 1,
#  '13': 3,
#  '2018': 1,
#  'Language': 1,
#  'English': 9,
#  'Character': 1,
#  'set': 21,
#  'encoding': 1,
#  'UTF-8': 1,
#  'START': 2,
#  'OF': 10,
#  'THIS': 5,
#  'PROJECT': 4,
#  'GUTENBERG': 3,
#  'EBOOK': 2,
#  'FRANKENSTEIN': 2,
#  'Produced': 2,
#  'Judith': 2,
#  'Boss': 2,
#  'Christy': 2,
#  'Phillips': 2,
#  'Lynn': 2,
#  'Hanninen': 2,
#  'David': 2,
#  'Meltzer': 2,
#  'HTML': 2,
#  'version': 3,
#  'Al': 2,
#  'Haines': 2,
#  'Further': 2,
#  'corrections': 2,
#  'Menno': 2,
#  'de': 3,
#  'Leeuw': 2,
#  'CONTENTS': 1,
#  'Letter': 8,
#  '1': 49,
#  '2': 7,
#  '3': 14,
#  '4': 9,
#  'Chapter': 48,
#  '5': 6,
#  '6': 4,
#  '7': 5,
#  '8': 7,
#  '9': 5,
#  '10': 2,
#  '11': 2,
#  '12': 2,
#  '14': 2,
#  '15': 2,
#  '16': 2,
#  '18': 2,
#  '19': 2,
#  '20': 3,
#  '21': 2,
#  '22': 2,
#  '23': 2,
#  '24': 2,
#  '_To': 4,
#  'Mrs': 4,
#  'Saville': 4,
#  'England': 21,
#  '_': 16,
#  'St': 5,
#  'Petersburgh': 3,
#  'Dec': 1,
#  '11th': 2,
#  'will': 198,
#  'rejoice': 1,
#  'to': 2154,
#  'hear': 17,
#  'that': 1019,
#  'disaster': 4,
#  'has': 65,
#  'accompanied': 9,
#  'commencement': 5,
#  'an': 213,
#  'enterprise': 10,
#  'which': 565,
#  'you': 548,
#  'have': 362,
#  'regarded': 6,
#  'such': 78,
#  'evil': 22,
#  'forebodings': 2,
#  'I': 2846,
#  'arrived': 29,
#  'here': 28,
#  'yesterday': 3,
#  'my': 1635,
#  'first': 108,
#  'task': 19,
#  'assure': 5,
#  'dear': 66,
#  'sister': 25,
#  'welfare': 2,
#  'increasing': 2,
#  'confidence': 4,
#  'in': 1134,
#  'success': 12,
#  'undertaking': 13,
#  'am': 124,
#  'already': 33,
#  'far': 39,
#  'north': 10,
#  'London': 8,
#  'as': 492,
#  'walk': 6,
#  'streets': 6,
#  'feel': 50,
#  'a': 1402,
#  'cold': 30,
#  'northern': 6,
#  'breeze': 10,
#  'play': 7,
#  'upon': 126,
#  'cheeks': 7,
#  'braces': 1,
#  'nerves': 3,
#  'fills': 5,
#  'me': 867,
#  'delight': 32,
#  'Do': 26,
#  'understand': 17,
#  'feeling': 27,
#  'travelled': 6,
#  'from': 388,
#  'regions': 6,
#  'towards': 93,
#  'advancing': 4,
#  'gives': 6,
#  'foretaste': 1,
#  'those': 88,
#  'icy': 3,
#  'climes': 1,
#  'Inspirited': 1,
#  'wind': 27,
#  'promise': 22,
#  'daydreams': 2,
#  'become': 33,
#  'more': 164,
#  'fervent': 2,
#  'vivid': 3,
#  'try': 4,
#  'vain': 13,
#  'be': 370,
#  'persuaded': 7,
#  'pole': 4,
#  'seat': 4,
#  'frost': 5,
#  'desolation': 6,
#  'ever': 77,
#  'presents': 3,
#  'itself': 22,
#  'imagination': 23,
#  'region': 4,
#  'beauty': 27,
#  'There': 18,
#  'Margaret': 10,
#  'sun': 45,
#  'visible': 6,
#  'its': 124,
#  'broad': 2,
#  'disk': 3,
#  'just': 19,
#  'skirting': 1,
#  'horizon': 6,
#  'diffusing': 1,
#  'perpetual': 4,
#  'splendour': 1,
#  'your': 248,
#  'leave': 21,
#  'put': 15,
#  'some': 137,
#  'trust': 6,
#  'preceding': 6,
#  'navigators': 3,
#  'there': 65,
#  'snow': 14,
#  'are': 189,
#  'banished': 5,
#  'sailing': 1,
#  'over': 57,
#  'calm': 20,
#  'sea': 31,
#  'we': 125,
#  'wafted': 4,
#  'land': 18,
#  'surpassing': 2,
#  'wonders': 5,
#  'every': 104,
#  'hitherto': 12,
#  'discovered': 34,
#  'on': 453,
#  'habitable': 1,
#  'globe': 2,
#  'Its': 5,
#  'productions': 2,
#  'features': 7,
#  'without': 37,
#  'example': 2,
#  'phenomena': 2,
#  'heavenly': 4,
#  'bodies': 3,
#  'undoubtedly': 1,
#  'undiscovered': 2,
#  'solitudes': 1,
#  'What': 36,
#  'not': 526,
#  'expected': 12,
#  'country': 55,
#  'eternal': 11,
#  'light': 40,
#  'discover': 17,
#  'wondrous': 7,
#  'power': 39,
#  'attracts': 1,
#  'needle': 1,
#  'regulate': 2,
#  'thousand': 27,
#  'celestial': 5,
#  'observations': 1,
#  'require': 2,
#  'only': 124,
#  'voyage': 15,
#  'render': 10,
#  'their': 176,
#  'seeming': 2,
#  'eccentricities': 1,
#  'consistent': 1,
#  'shall': 100,
#  'satiate': 1,
#  'ardent': 10,
#  'curiosity': 13,
#  'sight': 25,
#  'part': 43,
#  'world': 45,
#  'never': 63,
#  'before': 139,
#  'visited': 17,
#  'tread': 3,
#  'imprinted': 2,
#  'foot': 5,
#  'man': 132,
#  'These': 22,
#  'enticements': 2,
#  'they': 174,
#  'sufficient': 20,
#  'conquer': 1,
#  'all': 207,
#  'fear': 38,
#  'danger': 12,
#  'death': 76,
#  'induce': 4,
#  'commence': 13,
#  'laborious': 3,
#  'joy': 41,
#  'child': 34,
#  'feels': 2,
#  'when': 274,
#  'he': 478,
#  'embarks': 1,
#  'little': 56,
#  'boat': 16,
#  'his': 502,
#  'holiday': 1,
#  'mates': 1,
#  'expedition': 4,
#  'discovery': 18,
#  'up': 73,
#  'native': 28,
#  'river': 12,
#  'But': 138,
#  'supposing': 2,
#  'these': 135,
#  'conjectures': 1,
#  'false': 5,
#  'cannot': 50,
#  'contest': 1,
#  'inestimable': 1,
#  'benefit': 7,
#  'confer': 1,
#  'mankind': 11,
#  'last': 31,
#  'generation': 2,
#  'discovering': 3,
#  'passage': 9,
#  'near': 38,
#  'countries': 4,
#  'reach': 5,
#  'present': 30,
#  'so': 207,
#  'many': 67,
#  'months': 39,
#  'requisite': 1,
#  'ascertaining': 1,
#  'secret': 13,
#  'magnet': 1,
#  'if': 161,
#  'possible': 11,
#  'can': 101,
#  'effected': 1,
#  'mine': 28,
#  'reflections': 16,
#  'dispelled': 1,
#  'agitation': 14,
#  'began': 28,
#  'letter': 25,
#  'heart': 76,
#  'glow': 1,
#  'enthusiasm': 11,
#  'elevates': 2,
#  'heaven': 14,
#  'nothing': 30,
#  'contributes': 1,
#  'much': 43,
#  'tranquillise': 1,
#  'mind': 85,
#  'steady': 2,
#  'purpose': 19,
#  'point': 14,
#  'soul': 36,
#  'fix': 4,
#  'intellectual': 3,
#  'eye': 18,
#  'been': 190,
#  'favourite': 13,
#  'dream': 18,
#  'early': 14,
#  'years': 44,
#  'read': 30,
#  'ardour': 13,
#  'accounts': 3,
#  'various': 27,
#  'voyages': 4,
#  'made': 70,
#  'prospect': 13,
#  'arriving': 1,
#  'North': 3,
#  'Pacific': 1,
#  'Ocean': 2,
#  'through': 46,
#  'seas': 6,
#  'surround': 4,
#  'remember': 15,
#  'history': 19,
#  'purposes': 3,
#  'composed': 5,
#  'whole': 32,
#  'our': 122,
#  'good': 29,
#  'Uncle': 2,
#  'Thomas': 2,
#  'library': 3,
#  'My': 141,
#  'education': 6,
#  'was': 1019,
#  'neglected': 7,
#  'yet': 115,
#  'passionately': 1,
#  'fond': 6,
#  'reading': 4,
#  'volumes': 2,
#  'were': 307,
#  'study': 18,
#  'day': 80,
#  'night': 84,
#  'familiarity': 1,
#  'them': 127,
#  'increased': 12,
#  'regret': 7,
#  'had': 684,
#  'felt': 79,
#  'learning': 3,
#  'father': 133,
#  's': 87,
#  'dying': 5,
#  'injunction': 1,
#  'forbidden': 3,
#  'uncle': 8,
#  'allow': 14,
#  'embark': 1,
#  'seafaring': 1,
#  'life': 113,
#  'visions': 5,
#  'faded': 1,
#  'perused': 1,
#  'time': 97,
#  'poets': 4,
#  'whose': 50,
#  'effusions': 1,
#  'entranced': 1,
#  'lifted': 1,
#  'also': 68,
#  'became': 61,
#  'poet': 1,
#  'one': 187,
#  'year': 8,
#  'lived': 23,
#  'paradise': 2,
#  'own': 107,
#  'creation': 20,
#  'imagined': 9,
#  'might': 108,
#  'obtain': 10,
#  'niche': 1,
#  'temple': 1,
#  'where': 78,
#  'names': 16,
#  'Homer': 1,
#  'Shakespeare': 1,
#  'consecrated': 1,
#  'well': 41,
#  'acquainted': 20,
#  'failure': 3,
#  'how': 65,
#  'heavily': 3,
#  'bore': 7,
#  'disappointment': 7,
#  'inherited': 2,
#  'fortune': 9,
#  'cousin': 24,
#  'thoughts': 38,
#  'turned': 24,
#  'into': 124,
#  'channel': 1,
#  'earlier': 3,
#  'bent': 9,
#  'Six': 3,
#  'passed': 67,
#  'since': 25,
#  'resolved': 31,
#  'even': 82,
#  'now': 148,
#  'hour': 25,
#  'dedicated': 2,
#  'myself': 136,
#  'great': 45,
#  'commenced': 7,
#  'inuring': 1,
#  'body': 23,
#  'hardship': 2,
#  'whale-fishers': 1,
#  'several': 44,
#  'expeditions': 1,
#  'Sea': 2,
#  'voluntarily': 1,
#  'endured': 23,
#  'famine': 2,
#  'thirst': 14,
#  'want': 12,
#  'sleep': 20,
#  'often': 52,
#  'worked': 8,
#  'harder': 1,
#  'than': 112,
#  'common': 5,
#  'sailors': 10,
#  'during': 49,
#  'devoted': 13,
#  'nights': 5,
#  'mathematics': 3,
#  'theory': 4,
#  'medicine': 1,
#  'branches': 12,
#  'physical': 5,
#  'science': 28,
#  'naval': 1,
#  'adventurer': 1,
#  'derive': 3,
#  'greatest': 27,
#  'practical': 3,
#  'advantage': 4,
#  'Twice': 1,
#  'actually': 2,
#  'hired': 7,
#  'under-mate': 1,
#  'Greenland': 1,
#  'whaler': 1,
#  'acquitted': 2,
#  'admiration': 14,
#  'must': 73,
#  'proud': 2,
#  'captain': 4,
#  'offered': 2,
#  'second': 6,
#  'dignity': 4,
#  'vessel': 17,
#  'entreated': 6,
#  'remain': 22,
#  'earnestness': 3,
#  'valuable': 3,
#  'did': 115,
#  'consider': 9,
#  'services': 3,
#  'And': 39,
#  'do': 109,
#  'deserve': 3,
#  'accomplish': 2,
#  'ease': 3,
#  'luxury': 4,
#  'but': 553,
#  'preferred': 1,
#  'glory': 7,
#  'enticement': 1,
#  'wealth': 6,
#  'placed': 28,
#  'path': 20,
#  'Oh': 26,
#  'encouraging': 1,
#  'voice': 46,
#  'would': 182,
#  'answer': 20,
#  'affirmative': 2,
#  'courage': 18,
#  'resolution': 8,
#  'firm': 7,
#  'hopes': 23,
#  'fluctuate': 1,
#  'spirits': 31,
#  'depressed': 4,
#  'about': 54,
#  'proceed': 8,
#  'long': 47,
#  'difficult': 2,
#  'emergencies': 1,
#  'demand': 11,
#  'fortitude': 5,
#  'required': 7,
#  'raise': 6,
#  'others': 26,
#  'sometimes': 37,
#  'sustain': 6,
#  'theirs': 4,
#  'failing': 3,
#  'most': 89,
#  'favourable': 7,
#  'period': 16,
#  'travelling': 1,
#  'Russia': 2,
#  'They': 39,
#  'fly': 7,
#  'quickly': 26,
#  'sledges': 1,
#  'motion': 6,
#  'pleasant': 12,
#  'opinion': 3,
#  'agreeable': 5,
#  'stagecoach': 1,
#  'excessive': 3,
#  'wrapped': 4,
#  'furs': 2,
#  'dress': 6,
#  'adopted': 1,
#  'difference': 5,
#  'between': 19,
#  'walking': 7,
#  'deck': 8,
#  'remaining': 7,
#  'seated': 4,
#  'motionless': 6,
#  'hours': 34,
#  'exercise': 6,
#  'prevents': 2,
#  'blood': 19,
#  'freezing': 1,
#  'veins': 4,
#  'ambition': 8,
#  'lose': 8,
#  'post-road': 1,
#  'Archangel': 4,
#  'depart': 8,
#  'latter': 13,
#  'town': 26,
#  'fortnight': 5,
#  'three': 10,
#  'weeks': 6,
#  'intention': 3,
#  'hire': 1,
#  'ship': 8,
#  'easily': 19,
#  'done': 9,
#  'paying': 3,
#  'insurance': 1,
#  'owner': 5,
#  'engage': 3,
#  'think': 27,
#  'necessary': 18,
#  'among': 49,
#  'who': 166,
#  'accustomed': 10,
#  'whale-fishing': 1,
#  'intend': 6,
#  'sail': 5,
#  'until': 52,
#  'month': 9,
#  'return': 51,
#  'Ah': 7,
#  'question': 8,
#  'If': 52,
#  'succeed': 6,
#  'perhaps': 20,
#  'pass': 16,
#  'meet': 13,
#  'fail': 7,
#  'see': 51,
#  'again': 79,
#  'soon': 60,
#  'Farewell': 7,
#  'excellent': 13,
#  'Heaven': 7,
#  'shower': 1,
#  'down': 34,
#  'blessings': 2,
#  'save': 5,
#  'testify': 1,
#  'gratitude': 8,
#  'love': 59,
#  'kindness': 27,
#  'Your': 13,
#  'affectionate': 7,
#  'brother': 23,
#  'R': 2,
#  'Walton': 8,
#  '28th': 1,
#  'March': 3,
#  'How': 33,
#  'slowly': 3,
#  'passes': 2,
#  'encompassed': 4,
#  'Yet': 37,
#  'step': 7,
#  'taken': 33,
#  'occupied': 24,
#  'collecting': 5,
#  'whom': 81,
#  'engaged': 18,
#  'appear': 23,
#  'men': 43,
#  'depend': 2,
#  'certainly': 11,
#  'possessed': 37,
#  'dauntless': 2,
#  'able': 9,
#  'satisfy': 7,
#  'absence': 7,
#  'object': 21,
#  'severe': 5,
#  'friend': 70,
#  'glowing': 1,
#  'none': 17,
#  'participate': 2,
#  'assailed': 1,
#  'endeavour': 12,
#  'dejection': 2,
#  'commit': 3,
#  'paper': 3,
#  'true': 21,
#  'poor': 38,
#  'medium': 6,
#  'communication': 3,
#  'desire': 28,
#  'company': 5,
#  'could': 192,
#  'sympathise': 4,
#  'eyes': 104,
#  'reply': 4,
#  'deem': 1,
#  'romantic': 4,
#  'bitterly': 10,
#  'gentle': 34,
#  'courageous': 1,
#  'cultivated': 3,
#  'capacious': 1,
#  'tastes': 3,
#  'like': 59,
#  'approve': 2,
#  'amend': 1,
#  'plans': 7,
#  'repair': 1,
#  'faults': 1,
#  'too': 30,
#  'execution': 8,
#  'impatient': 4,
#  'difficulties': 2,
#  'still': 64,
#  'greater': 25,
#  'self-educated': 1,
#  'fourteen': 1,
#  'ran': 7,
#  'wild': 12,
#  'books': 12,
#  'At': 27,
#  'age': 12,
#  'celebrated': 2,
#  'ceased': 11,
#  'important': 2,
#  'benefits': 1,
#  'conviction': 6,
#  'perceived': 26,
#  'necessity': 5,
#  'becoming': 4,
#  'languages': 5,
#  'Now': 7,
#  'twenty-eight': 1,
#  'reality': 10,
#  'illiterate': 1,
#  'schoolboys': 1,
#  'fifteen': 2,
#  'It': 101,
#  'thought': 74,
#  'extended': 2,
#  'magnificent': 8,
#  'painters': 1,
#  'call': 13,
#  '_keeping': 1,
#  'greatly': 12,
#  'need': 9,
#  'sense': 12,
#  'enough': 12,
#  'despise': 2,
#  'affection': 40,
#  'Well': 3,
#  'useless': 9,
#  'complaints': 2,
#  'find': 23,
#  'wide': 8,
#  'ocean': 11,
#  'nor': 31,
#  'merchants': 1,
#  'seamen': 1,
#  'feelings': 76,
#  'unallied': 1,
#  'dross': 1,
#  'human': 57,
#  'nature': 48,
#  'beat': 5,
#  'rugged': 4,
#  'bosoms': 1,
#  'lieutenant': 2,
#  'instance': 1,
#  'wonderful': 16,
#  'madly': 1,
#  'desirous': 3,
#  'rather': 27,
#  'word': 14,
#  'phrase': 5,
#  'characteristically': 1,
#  'advancement': 1,
#  'profession': 2,
#  'He': 131,
#  'Englishman': 2,
#  'midst': 3,
#  'national': 1,
#  'professional': 1,
#  'prejudices': 2,
#  'unsoftened': 1,
#  'cultivation': 4,
#  'retains': 1,
#  'noblest': 1,
#  'endowments': 1,
#  'humanity': 6,
#  'him': 222,
#  'board': 6,
#  'whale': 1,
#  'finding': 7,
#  'unemployed': 1,
#  'city': 12,
#  'assist': 6,
#  'master': 8,
#  'person': 21,
#  'disposition': 6,
#  'remarkable': 2,
#  'gentleness': 10,
#  'mildness': 3,
#  'discipline': 1,
#  'circumstance': 10,
#  'added': 7,
#  'well-known': 4,
#  'integrity': 3,
#  'very': 75,
#  'A': 47,
#  'youth': 21,
#  'solitude': 15,
#  'best': 12,
#  'spent': 25,
#  'feminine': 2,
#  'fosterage': 1,
#  'refined': 3,
#  'groundwork': 1,
#  'character': 7,
#  'overcome': 16,
#  'intense': 7,
#  'distaste': 1,
#  'usual': 5,
#  'brutality': 2,
#  'exercised': 2,
#  'believed': 13,
#  'heard': 62,
#  'mariner': 1,
#  'equally': 4,
#  'noted': 1,
#  'kindliness': 1,
#  'respect': 5,
#  'obedience': 1,
#  'paid': 12,
#  'crew': 1,
#  'peculiarly': 5,
#  'fortunate': 7,
#  'being': 95,
#  'secure': 8,
#  'manner': 31,
#  'lady': 11,
#  'owes': 1,
#  'happiness': 49,
#  'her': 358,
#  'briefly': 2,
#  'story': 13,
#  'Some': 11,
#  'ago': 7,
#  'loved': 29,
#  'young': 29,
#  'Russian': 1,
#  'moderate': 4,
#  'having': 21,
#  'amassed': 1,
#  'considerable': 10,
#  'sum': 5,
#  'prize-money': 2,
#  'girl': 28,
#  'consented': 5,
#  'match': 1,
#  'saw': 94,
#  'mistress': 3,
#  'once': 27,
#  'destined': 5,
#  'ceremony': 3,
#  'she': 183,
#  'bathed': 1,
#  'tears': 29,
#  'throwing': 2,
#  'herself': 14,
#  'feet': 13,
#  'spare': 3,
#  'confessing': 1,
#  'same': 64,
#  'another': 44,
#  'consent': 12,
#  'union': 16,
#  'generous': 5,
#  'reassured': 1,
#  'suppliant': 1,
#  'informed': 4,
#  'name': 16,
#  'lover': 8,
#  'instantly': 16,
#  'abandoned': 3,
#  'pursuit': 16,
#  'bought': 3,
#  'farm': 1,
#  'money': 11,
#  'designed': 1,
#  'remainder': 5,
#  'bestowed': 13,
#  'rival': 1,
#  'together': 9,
#  'remains': 13,
#  'purchase': 1,
#  'stock': 3,
#  'then': 104,
#  'himself': 37,
#  'solicited': 2,
#  'woman': 22,
#  'marriage': 15,
#  'old': 52,
#  'decidedly': 1,
#  'refused': 3,
#  'thinking': 2,
#  'bound': 17,
#  'honour': 10,
#  'found': 90,
#  'inexorable': 3,
#  'quitted': 22,
#  'returned': 31,
#  'former': 14,
#  'married': 4,
#  'according': 3,
#  'inclinations': 2,
#  'noble': 11,
#  'fellow': 28,
#  'exclaim': 1,
#  'wholly': 3,
#  'uneducated': 1,
#  'silent': 15,
#  'Turk': 10,
#  'kind': 34,
#  'ignorant': 10,
#  'carelessness': 3,
#  'attends': 1,
#  'while': 59,
#  'renders': 4,
#  'conduct': 8,
#  'astonishing': 8,
#  'detracts': 1,
#  'interest': 13,
#  'sympathy': 19,
#  'otherwise': 8,
#  'command': 4,
#  'suppose': 7,
#  'because': 17,
#  'complain': 1,
#  'conceive': 10,
#  'consolation': 18,
#  'toils': 8,
#  'know': 49,
#  'wavering': 1,
#  'resolutions': 2,
#  'Those': 3,
#  'fixed': 24,
#  'fate': 18,
#  'delayed': 5,
#  'weather': 9,
#  'permit': 5,
#  'embarkation': 2,
#  'winter': 12,
#  'dreadfully': 3,
#  'spring': 11,
#  'promises': 2,
#  'considered': 11,
#  'remarkably': 3,
#  'season': 9,
#  'sooner': 4,
#  'rashly': 3,
#  'sufficiently': 3,
#  'confide': 4,
#  'prudence': 1,
#  'considerateness': 1,
#  'whenever': 2,
#  'safety': 10,
#  'committed': 13,
#  'care': 22,
#  'describe': 15,
#  ...}

# %%
import operator
sorted_words = sorted(words.items(), key=operator.itemgetter(1), reverse=True)
#itemgetter(1) gets the second piece from each item, in this case the value

# %%
sorted_words
# Out:
# [('zip', 1),
#  ('zeal', 4),
#  ('youthful', 3),
#  ('youth', 21),
#  ('yourselves', 1),
#  ('yourself', 28),
#  ('yours', 4),
#  ('your', 248),
#  ('youngster', 1),
#  ('youngest', 1),
#  ('younger', 9),
#  ('young', 29),
#  ('you', 548),
#  ('yon', 1),
#  ('yielded', 3),
#  ('yield', 5),
#  ('yet', 115),
#  ('yesternight', 1),
#  ('yesterday', 3),
#  ('yellow', 4),
#  ('years', 44),
#  ('yearned', 1),
#  ('year', 8),
#  ('ye', 4),
#  ('yards', 1),
#  ('yard', 1),
#  ('www', 6),
#  ('wrung', 1),
#  ('wrought', 1),
#  ('wrote', 4),
#  ('wrongfully', 1),
#  ('wrong', 1),
#  ('written', 7),
#  ('writings', 1),
#  ('writing', 6),
#  ('writhing', 1),
#  ('writhed', 2),
#  ('writes', 1),
#  ('writers', 2),
#  ('write', 10),
#  ('wrinkled', 3),
#  ('wretchedness', 14),
#  ('wretchedly', 1),
#  ('wretched', 23),
#  ('wretch', 24),
#  ('wrestle', 1),
#  ('wrenched', 1),
#  ('wrecked', 2),
#  ('wreck', 5),
#  ('wreaths', 1),
#  ('wreaked', 1),
#  ('wreak', 3),
#  ('wrapping', 1),
#  ('wrapped', 4),
#  ('wrap', 1),
#  ('wounds', 3),
#  ('wounded', 1),
#  ('wound', 6),
#  ('wouldst', 1),
#  ('would-be', 1),
#  ('would', 182),
#  ('worthy', 5),
#  ('worth', 5),
#  ('worst', 3),
#  ('worship', 1),
#  ('worse', 4),
#  ('worn', 3),
#  ('worms', 1),
#  ('worm', 4),
#  ('worldly-minded', 1),
#  ('world', 45),
#  ('workshop', 1),
#  ('works', 40),
#  ('workman', 1),
#  ('working', 2),
#  ('worked', 8),
#  ('work', 77),
#  ('wore', 3),
#  ('words', 54),
#  ('word', 14),
#  ('woods', 12),
#  ('wood', 25),
#  ('wont', 1),
#  ('wondrously', 1),
#  ('wondrous', 7),
#  ('wonders', 5),
#  ('wonderfully', 1),
#  ('wonderful_', 1),
#  ('wonderful', 16),
#  ('wonder', 21),
#  ('won', 3),
#  ('women', 4),
#  ('woman', 22),
#  ('woes', 2),
#  ('woeful', 2),
#  ('woe', 6),
#  ('witnesses', 9),
#  ('witnessed', 1),
#  ('witness', 3),
#  ('withstand', 2),
#  ('without', 37),
#  ('within', 35),
#  ('withhold', 1),
#  ('withered', 1),
#  ('withdrew', 2),
#  ('withdrawn', 1),
#  ('with', 705),
#  ('wishing', 2),
#  ('wishes', 7),
#  ('wished', 20),
#  ('wish', 24),
#  ('wisest', 1),
#  ('wiser', 1),
#  ('wise', 1),
#  ('wisdom', 3),
#  ('wiping', 1),
#  ('wiped', 1),
#  ('wipe', 1),
#  ('winter', 12),
#  ('winning', 1),
#  ('wings', 1),
#  ('winged', 1),
#  ('wine', 1),
#  ('winds', 8),
#  ('windows', 5),
#  ('window', 9),
#  ('windings', 3),
#  ('winding', 1),
#  ('wind', 27),
#  ('win', 2),
#  ('wilt', 1),
#  ('willowy', 1),
#  ('willow', 1),
#  ('willingly', 4),
#  ('will', 198),
#  ('wiliness', 1),
#  ('wilds', 3),
#  ('wildness', 3),
#  ('wildest', 3),
#  ('wild', 12),
#  ('wife', 11),
#  ('width', 1),
#  ('widow', 2),
#  ('widest', 2),
#  ('wider', 1),
#  ('wide', 8),
#  ('wickedness', 6),
#  ('wicked', 2),
#  ('why', 17),
#  ('whose', 50),
#  ('whom', 81),
#  ('wholly', 3),
#  ('wholesome', 1),
#  ('whole', 32),
#  ('who', 166),
#  ('whither', 5),
#  ('whitewashed', 1),
#  ('whiteness', 1),
#  ('white', 10),
#  ('whispers', 1),
#  ('whispered', 4),
#  ('whisper', 2),
#  ('whirlwinds', 2),
#  ('whirlwind', 1),
#  ('whirled', 1),
#  ('whine', 1),
#  ('whilst', 9),
#  ('while', 59),
#  ('which', 565),
#  ('whether', 14),
#  ('wherever', 2),
#  ('wherefore', 2),
#  ('where', 78),
#  ('whenever', 2),
#  ('whence', 2),
#  ('when', 274),
#  ('wheel', 1),
#  ('whatsoever', 3),
#  ('whatever', 2),
#  ('what', 97),
#  ('whaler', 1),
#  ('whale-fishing', 1),
#  ('whale-fishers', 1),
#  ('whale', 1),
#  ('wet', 6),
#  ('western', 1),
#  ('west', 2),
#  ('wert', 2),
#  ('were', 307),
#  ('wept', 16),
#  ('went', 20),
#  ('well-known', 4),
#  ('well-being', 1),
#  ('well', 41),
#  ('welfare', 2),
#  ('welcomed', 5),
#  ('welcome', 6),
#  ('weight', 7),
#  ('weighs', 1),
#  ('weighed', 6),
#  ('weigh', 1),
#  ('weeps', 1),
#  ('weeping', 4),
#  ('weep', 11),
#  ('weeks', 6),
#  ('week', 8),
#  ('wedding-night_', 2),
#  ('wedding-night', 3),
#  ('web', 3),
#  ('weather', 9),
#  ('wearying', 1),
#  ('weary', 1),
#  ('wears', 1),
#  ('wearing', 1),
#  ('wearily', 1),
#  ('wearied', 1),
#  ('wear', 1),
#  ('weapons', 1),
#  ('wean', 1),
#  ('wealth', 6),
#  ('weakness', 3),
#  ('weakened', 2),
#  ('weaken', 1),
#  ('weak', 5),
#  ('we', 125),
#  ('ways', 2),
#  ('way', 20),
#  ('waves', 14),
#  ('wavering', 1),
#  ('waved', 2),
#  ('watery', 2),
#  ('waters', 11),
#  ('waterfalls', 1),
#  ('water-spout', 1),
#  ('water', 16),
#  ('watching', 13),
#  ('watchful', 3),
#  ('watched', 4),
#  ('watch', 8),
#  ('wasting', 1),
#  ('wasted', 3),
#  ('waste', 4),
#  ('was', 1019),
#  ('wars', 1),
#  ('warring', 1),
#  ('warranties', 1),
#  ('warmth', 11),
#  ('warmly', 1),
#  ('warmest', 2),
#  ('warmer', 2),
#  ('warmed', 5),
#  ('warm', 8),
#  ('warbling', 1),
#  ('war', 2),
#  ('wants', 3),
#  ('wantonness', 1),
#  ('wantonly', 2),
#  ('want', 12),
#  ('wanderings', 3),
#  ('wandering', 3),
#  ('wanderer', 2),
#  ('wandered', 14),
#  ('wander', 4),
#  ('wand', 1),
#  ('wan', 1),
#  ('walls', 4),
#  ('wallet', 1),
#  ('wall', 1),
#  ('walks', 4),
#  ('walking', 7),
#  ('walked', 16),
#  ('walk', 6),
#  ('waking', 1),
#  ('waiting', 2),
#  ('waited', 8),
#  ('wait', 4),
#  ('wail', 1),
#  ('wafted', 4),
#  ('vulture', 1),
#  ('vulgar', 1),
#  ('voyages', 4),
#  ('voyage', 15),
#  ('vows', 1),
#  ('vowed', 2),
#  ('vow', 4),
#  ('volunteers', 5),
#  ('volunteer', 1),
#  ('voluntary', 2),
#  ('voluntarily', 1),
#  ('volumes', 2),
#  ('volume', 4),
#  ('volcano', 1),
#  ('void', 3),
#  ('voices', 4),
#  ('voiceless', 1),
#  ('voice', 46),
#  ('vivid', 3),
#  ('vivacity', 3),
#  ('vital', 1),
#  ('visits', 4),
#  ('visitor', 1),
#  ('visitings', 1),
#  ('visited', 17),
#  ('visit', 20),
#  ('visions', 5),
#  ('vision', 3),
#  ('visible', 6),
#  ('visage', 2),
#  ('virus', 1),
#  ('virtuous', 4),
#  ('virtues', 8),
#  ('virtue', 12),
#  ('violently', 6),
#  ('violent', 8),
#  ('violence', 9),
#  ('violates', 1),
#  ('vintage', 2),
#  ('vineyards', 1),
#  ('vines', 4),
#  ('villains', 1),
#  ('villain', 1),
#  ('villagers', 3),
#  ('village', 12),
#  ('villa', 1),
#  ('vile', 1),
#  ('vigour', 2),
#  ('vigorous', 1),
#  ('vigilance', 1),
#  ('views', 3),
#  ('viewing', 1),
#  ('viewed', 5),
#  ('view', 15),
#  ('victory', 1),
#  ('victorious', 1),
#  ('victims', 4),
#  ('victim', 16),
#  ('vicious', 3),
#  ('vicinity', 1),
#  ('vices', 2),
#  ('vice', 8),
#  ('viands', 1),
#  ('vexations', 1),
#  ('vestige', 1),
#  ('vessels', 3),
#  ('vessel', 17),
#  ('very', 75),
#  ('version', 3),
#  ('verge', 1),
#  ('verdure', 2),
#  ('verdant', 2),
#  ('ventures', 1),
#  ('ventured', 3),
#  ('venture', 1),
#  ('venting', 1),
#  ('vent', 2),
#  ('venom', 1),
#  ('vengeance', 21),
#  ('venerable', 4),
#  ('veins', 4),
#  ('veiled', 1),
#  ('veil', 3),
#  ('vehicle', 1),
#  ('vehement', 1),
#  ('vegetables', 2),
#  ('vaults', 1),
#  ('vast', 11),
#  ('various', 27),
#  ('variety', 4),
#  ('variegated', 1),
#  ('varied', 2),
#  ('variable', 1),
#  ('vanquished', 1),
#  ('vanished', 6),
#  ('vanish', 4),
#  ('vampire', 1),
#  ('valued', 3),
#  ('value', 3),
#  ('valuable', 3),
#  ('valleys', 1),
#  ('valley', 9),
#  ('vales', 1),
#  ('vale', 1),
#  ('vainly', 4),
#  ('vain', 13),
#  ('vagrants', 1),
#  ('vagabond', 1),
#  ('vacillating', 1),
#  ('vacant', 1),
#  ('vacancy', 2),
#  ('utterly', 11),
#  ('uttering', 1),
#  ('uttered', 9),
#  ('utterance', 3),
#  ('utter', 11),
#  ('utmost', 6),
#  ('utility', 3),
#  ('utensils', 2),
#  ('usually', 2),
#  ('usual', 5),
#  ('using', 5),
#  ('uses', 3),
#  ('user', 3),
#  ('useless', 9),
#  ('usefulness', 2),
#  ('useful', 4),
#  ('used', 6),
#  ('use', 17),
#  ('usage', 1),
#  ('us', 61),
#  ('urged', 9),
#  ('upright', 2),
#  ('upon', 126),
#  ('updated', 1),
#  ('up', 73),
#  ('unworthy', 2),
#  ('unworthiness', 1),
#  ('unwillingness', 1),
#  ('unwillingly', 1),
#  ('unwilling', 4),
#  ('unwholesome', 2),
#  ('unwearied', 1),
#  ('unvisited', 1),
#  ('unveiled', 1),
#  ('unutterable', 1),
#  ('unusual', 3),
#  ('untrodden', 1),
#  ('untimely', 2),
#  ('until', 52),
#  ('untaught', 1),
#  ('untamed', 1),
#  ('unsympathised', 1),
#  ('unsupported', 1),
#  ('unsullied', 1),
#  ('unsuccessful', 1),
#  ('unstained', 1),
#  ('unspeakable', 2),
#  ('unsolicited', 1),
#  ('unsoftened', 1),
#  ('unsocial', 1),
#  ('unsettled', 1),
#  ('unseen', 1),
#  ('unsatisfied', 2),
#  ('unsatisfactory', 1),
#  ('unrestrained', 2),
#  ('unreservedly', 1),
#  ('unremitting', 3),
#  ('unremitted', 1),
#  ('unrelaxed', 1),
#  ('unravel', 1),
#  ('unquiet', 1),
#  ('unquenched', 1),
#  ('unqualified', 1),
#  ('unprotected', 2),
#  ('unprejudiced', 2),
#  ('unpractised', 1),
#  ('unplastered', 1),
#  ('unperceived', 2),
#  ('unparalleled', 5),
#  ('unobserving', 1),
#  ('unnatural', 3),
#  ('unmolested', 1),
#  ('unmingled', 3),
#  ('unlocked', 1),
#  ('unlink', 1),
#  ('unlimited', 1),
#  ('unlike', 7),
#  ('unless', 7),
#  ('unlawful', 1),
#  ('unknown', 7),
#  ('unkindness', 1),
#  ('unjustly', 2),
#  ('unjust', 2),
#  ('university', 7),
#  ('universal', 1),
#  ('united', 6),
#  ('unite', 1),
#  ('union', 16),
#  ('uninterrupted', 1),
#  ('uninteresting', 1),
#  ('uninterested', 1),
#  ('unintelligible', 1),
#  ('uniform', 4),
#  ('unheard-of', 1),
#  ('unhappy', 18),
#  ('unhappiness', 4),
#  ('unhallowed', 4),
#  ('unguarded', 2),
#  ('ungratitude', 1),
#  ('ungazed', 1),
#  ('unfulfilled', 2),
#  ('unfortunately', 3),
#  ('unfortunate', 15),
#  ('unformed', 1),
#  ('unfolding', 2),
#  ('unfolded', 2),
#  ('unfold', 1),
#  ('unfitted', 1),
#  ('unfitness', 1),
#  ('unfit', 2),
#  ('unfinished', 2),
#  ('unfeeling', 2),
#  ('unfavourable', 2),
#  ('unfashioned', 1),
#  ('unfair', 2),
#  ('unfailing', 1),
#  ('unexplored', 2),
#  ('unexpected', 2),
#  ('unexampled', 1),
#  ('uneven', 1),
#  ('unequalled', 1),
#  ('unequal', 1),
#  ('unenforceability', 1),
#  ('unemployed', 1),
#  ('uneducated', 1),
#  ('uneasy', 3),
#  ('uneasiness', 2),
#  ('unearthly', 3),
#  ('undulations', 1),
#  ('undoubtedly', 1),
#  ('undivided', 1),
#  ('undisturbed', 3),
#  ('undiscovered', 2),
#  ('underwood', 1),
#  ('underwent', 1),
#  ('undertaking', 13),
#  ('undertake', 4),
#  ('understood', 14),
#  ('understanding', 5),
#  ('understand', 17),
#  ('undergone', 1),
#  ('undergo', 1),
#  ('under-mate', 1),
#  ('under', 29),
#  ('undeceiving', 1),
#  ('undeceive', 1),
#  ('uncovered', 1),
#  ('uncouth', 3),
#  ('uncontrollably', 1),
#  ('uncontrollable', 2),
#  ('unconscious', 2),
#  ('uncommonly', 1),
#  ('uncommon', 3),
#  ('uncle', 8),
#  ('unchecked', 2),
#  ('unchained', 1),
#  ('uncertain', 3),
#  ('unceasing', 1),
#  ('unbridled', 1),
#  ('unbounded', 3),
#  ('unbending', 1),
#  ('unbelief', 1),
#  ('unavoidable', 1),
#  ('unalterable', 1),
#  ('unallied', 1),
#  ('unadept', 1),
#  ('unacquainted', 4),
#  ('unaccountable', 1),
#  ('unable', 21),
#  ('unabated', 1),
#  ('ultimately', 2),
#  ('ugly', 3),
#  ('ugliness', 2),
#  ('tyros', 1),
#  ('tyrants', 1),
#  ('tyrant', 1),
#  ('tyranny', 1),
#  ('tyrannical', 1),
#  ('types', 1),
#  ('type', 2),
#  ('txt', 1),
#  ('two', 33),
#  ('twinkling', 1),
#  ('twice', 1),
#  ('twenty-eight', 1),
#  ('twenty', 4),
#  ('twelve', 1),
#  ('tutored', 1),
#  ('turns', 2),
#  ('turnkeys', 2),
#  ('turning', 5),
#  ('turned', 24),
#  ('turn', 12),
#  ('turmoil', 1),
#  ('turbulence', 1),
#  ('tumultuous', 3),
#  ('tumult', 4),
#  ('try', 4),
#  ('truth', 14),
#  ('trust', 6),
#  ('truly', 5),
#  ('truest', 1),
#  ('true', 21),
#  ('truce', 1),
#  ('troubled', 7),
#  ('trouble', 3),
#  ('trod', 1),
#  ('triumphed', 2),
#  ('triumphantly', 1),
#  ('triumphant', 1),
#  ('triumph', 6),
#  ('trifling', 2),
#  ('trifled', 1),
#  ('tried', 14),
#  ('trickling', 1),
#  ('trickle', 1),
#  ('tribute', 2),
#  ('trials', 1),
#  ('trial', 10),
#  ('tremulous', 1),
#  ('tremendous', 7),
#  ('trembling', 6),
#  ('trembled', 11),
#  ('tremble', 6),
#  ('trees', 20),
#  ('tree', 5),
#  ('treble', 1),
#  ('treatment', 5),
#  ('treating', 1),
#  ('treated', 1),
#  ('treasures', 3),
#  ('treasure', 2),
#  ('treading', 1),
#  ('tread', 3),
#  ('treachery', 2),
#  ('treacherous', 1),
#  ('traversing', 1),
#  ('traversed', 6),
#  ('traverse', 2),
#  ('travels', 4),
#  ('travelling', 1),
#  ('travellers', 2),
#  ('traveller', 5),
#  ('travelled', 6),
#  ('travel', 4),
#  ('trash', 1),
#  ('transversely', 1),
#  ('transported', 4),
#  ('transport', 1),
#  ('transparent', 1),
#  ('transmuted', 1),
#  ('transmit', 1),
#  ('transitory', 4),
#  ('transfer', 1),
#  ('transcription', 1),
#  ('transcribe', 1),
#  ('transcendent', 1),
#  ('transaction', 1),
#  ('transacted', 1),
#  ('tranquilly', 1),
#  ('tranquillity', 14),
#  ('tranquillised', 1),
#  ('tranquillise', 1),
#  ('tranquil', 7),
#  ('trance', 1),
#  ('trampled', 1),
#  ('trample', 2),
#  ('traitor', 1),
#  ('trait', 2),
#  ('trains', 1),
#  ('trained', 1),
#  ('train', 6),
#  ('tragedy', 1),
#  ('trader', 1),
#  ('trademark', 10),
#  ('trade', 2),
#  ('track', 3),
#  ('tracing', 1),
#  ('traces', 2),
#  ('traced', 1),
#  ('trace', 9),
#  ('towns', 4),
#  ('town', 26),
#  ('towers', 1),
#  ('towering', 1),
#  ('towered', 1),
#  ('towards', 93),
#  ('toward', 3),
#  ('tour', 4),
#  ('touching', 2),
#  ('touched', 5),
#  ('touch', 1),
#  ('totally', 3),
#  ('total', 1),
#  ('torturing', 1),
#  ('tortures', 5),
#  ('torturer', 1),
#  ('tortured', 4),
#  ('torture', 12),
#  ('torrents', 2),
#  ('torrent', 2),
#  ('torpor', 2),
#  ('torn', 5),
#  ('torments', 3),
#  ('tormentor', 1),
#  ('tormenting', 2),
#  ('tormented', 5),
#  ('torment', 4),
#  ('tore', 5),
#  ('torches', 1),
#  ('torch', 1),
#  ('topic', 1),
#  ('top', 2),
#  ('tools', 3),
#  ('took', 36),
#  ('too', 30),
#  ('tongues', 1),
#  ('tongue', 1),
#  ('tones', 3),
#  ('tone', 3),
#  ('tomorrow', 2),
#  ('tomb', 3),
#  ('tolerated', 1),
#  ('tolerably', 1),
#  ('tolerable', 1),
#  ('told', 14),
#  ('tokens', 1),
#  ('toilsome', 1),
#  ('toils', 8),
#  ('toiled', 1),
#  ('toil', 7),
#  ('together', 9),
#  ('today', 2),
#  ('to', 2154),
#  ('title', 1),
#  ('tingling', 2),
#  ('tingle', 1),
#  ('tinged', 2),
#  ('timorous', 1),
#  ('timid', 1),
#  ('times', 11),
#  ('time', 97),
#  ('till', 2),
#  ('ties', 5),
#  ('tie', 1),
#  ('tidings', 2),
#  ('tide', 2),
#  ('thyself', 1),
#  ('thy', 18),
#  ('thus', 50),
#  ('thunderstorm', 1),
#  ('thunders', 1),
#  ('thunder', 8),
#  ('thrust', 2),
#  ('thrush', 2),
#  ('thrown', 9),
#  ('throwing', 2),
#  ('throw', 4),
#  ('throughout', 1),
#  ('through', 46),
#  ('throbbings', 1),
#  ('throats', 1),
#  ('throat', 3),
#  ('thrill', 2),
#  ('thrice-accursed', 1),
#  ('threw', 13),
#  ('threshold', 1),
#  ('three', 10),
#  ('threats', 4),
#  ('threatening', 1),
#  ('threatened', 5),
#  ('threaten', 1),
#  ('threat', 7),
#  ('thousands', 3),
#  ('thousand', 27),
#  ('thoughts', 38),
#  ('thoughtlessly', 1),
#  ('thoughtfulness', 1),
#  ('thoughtful', 1),
#  ('thought', 74),
#  ('thou', 14),
#  ('those', 88),
#  ('thither', 1),
#  ('this', 363),
#  ('thirty', 1),
#  ('thirteen', 1),
#  ('thirsting', 1),
#  ('thirsted', 2),
#  ('thirst', 14),
#  ('third', 2),
#  ('thinner', 1),
#  ('thinks', 1),
#  ('thinking', 2),
#  ('think', 27),
#  ('things', 11),
#  ('thing', 11),
#  ('thine', 3),
#  ('thin', 4),
#  ('thickly', 1),
#  ('thickened', 1),
#  ('thick', 7),
#  ('they', 174),
#  ('these', 135),
#  ('therefore', 37),
#  ('there', 65),
#  ('theory', 4),
#  ('theories', 1),
#  ('thenceforth', 2),
#  ('thence', 3),
#  ('then', 104),
#  ('themselves', 12),
#  ('theme', 1),
#  ('them', 127),
#  ('theirs', 4),
#  ('their', 176),
#  ('thee', 10),
#  ('the', 4069),
#  ('thatch', 1),
#  ('that', 1019),
#  ('thanks', 2),
#  ('thankfulness', 1),
#  ('thanked', 4),
#  ('thank', 7),
#  ('than', 112),
#  ('texture', 1),
#  ('testimony', 1),
#  ('testimonies', 1),
#  ('testify', 1),
#  ('tertiary', 1),
#  ('terrors', 1),
#  ('terror', 10),
#  ('terrified', 2),
#  ('terrifically', 1),
#  ('terrific', 7),
#  ('terribly', 2),
#  ('terrible', 10),
#  ('terms', 27),
#  ('termination', 1),
#  ('terminated', 1),
#  ('terminate', 1),
#  ('term', 1),
#  ('tenth', 1),
#  ('tenfold', 1),
#  ('tenets', 1),
#  ('tenement', 1),
#  ('tenderness', 4),
#  ('tenderly', 5),
#  ('tenderest', 2),
#  ('tender', 1),
#  ('tendency', 1),
#  ('tended', 1),
#  ('tend', 1),
#  ('ten-thousandth', 1),
#  ('ten', 7),
#  ('tempted', 4),
#  ('temptation', 3),
#  ('temporary', 2),
#  ('temples', 1),
#  ('temple', 1),
#  ('tempest', 4),
#  ('temperature', 2),
#  ('temper', 6),
#  ('tell', 9),
#  ('telescopes', 1),
#  ('teeth', 8),
#  ('tedious', 4),
#  ('teased', 1),
#  ('tears', 29),
#  ('tearing', 2),
#  ('tearful', 1),
#  ('tear', 8),
#  ('teachers', 1),
#  ('teacher', 1),
#  ('teach', 1),
#  ('taxes', 1),
#  ('tax', 6),
#  ('taunt', 1),
#  ('taught', 7),
#  ('tastes', 3),
#  ('tasted', 2),
#  ('taste', 5),
#  ('task', 19),
#  ('tarnish', 1),
#  ('tardily', 1),
#  ('tapped', 2),
#  ('tapers', 1),
#  ('tangible', 1),
#  ('tamer', 1),
#  ('tall', 3),
#  ('talks', 1),
#  ('talking', 2),
#  ('talked', 5),
#  ('talk', 3),
#  ('tales', 2),
#  ('talents', 1),
#  ('talent', 4),
#  ('tale', 32),
#  ('taking', 8),
#  ('takes', 2),
#  ('taken', 33),
#  ('take', 20),
#  ('tainted', 1),
#  ('tackle', 1),
#  ('table', 1),
#  ('systems', 2),
#  ('system', 2),
#  ('synonymous', 1),
#  ('syndics', 1),
#  ('syndic', 1),
#  ('symptoms', 3),
#  ('sympathy', 19),
#  ('sympathising', 2),
#  ('sympathised', 5),
#  ('sympathise', 4),
#  ('sympathies', 4),
#  ('symmetry', 1),
#  ('sworn', 2),
#  ('swore', 1),
#  ('sword', 1),
#  ('swimming', 1),
#  ('swim', 1),
#  ('swiftness', 4),
#  ('swifter', 1),
#  ('swept', 3),
#  ('swells', 1),
#  ('swelling', 3),
#  ('swelled', 3),
#  ('swell', 1),
#  ('sweetness', 3),
#  ('sweetest', 1),
#  ('sweeter', 1),
#  ('sweet', 22),
#  ('swear', 8),
#  ('sway', 1),
#  ('swamp', 1),
#  ('swallowed', 5),
#  ('swallow', 1),
#  ('sustenance', 2),
#  ('sustained', 5),
#  ('sustain', 6),
#  ('suspicious', 1),
#  ('suspicions', 1),
#  ('suspicion', 4),
#  ('suspense', 4),
#  ('suspended', 2),
#  ('suspect', 2),
#  ('susceptible', 2),
#  ('survivors', 2),
#  ('surviving', 1),
#  ('survive', 6),
#  ('surrounding', 2),
#  ('surrounded', 18),
#  ('surround', 4),
#  ('surprising', 2),
#  ('surprised', 13),
#  ('surprise', 8),
#  ('surpassing', 2),
#  ('surpassed', 1),
#  ('surmounting', 1),
#  ('surmounted', 1),
#  ('surmount', 2),
#  ('surgeon', 1),
#  ('surface', 2),
#  ('surely', 10),
#  ('sure-footed', 1),
#  ('sure', 2),
#  ('supreme', 2),
#  ('suppressing', 1),
#  ('suppress', 2),
#  ('supposition', 2),
#  ('supposing', 2),
#  ('supposed', 10),
#  ('suppose', 7),
#  ('supported', 5),
#  ('support', 17),
#  ('supply', 3),
#  ('supplied', 2),
#  ('supplication', 1),
#  ('suppliant', 1),
#  ('supple', 2),
#  ('superstition', 1),
#  ('superscription', 1),
#  ('supernatural', 4),
#  ('superiors', 1),
#  ('superior', 10),
#  ('superhuman', 1),
#  ('superfluous', 1),
#  ('sunshine', 4),
#  ('sunset', 2),
#  ('sunrise', 1),
#  ('sunny', 1),
#  ('sunlight', 1),
#  ('sunk', 9),
#  ('sun', 45),
#  ('summoned', 1),
#  ('summits', 5),
#  ('summit', 8),
#  ('summers', 1),
#  ('summer', 7),
#  ('sum', 5),
#  ('sullen', 2),
#  ('suited', 1),
#  ('suit', 1),
#  ('suicide', 1),
#  ('suggestion', 2),
#  ('suggested', 2),
#  ('suffocated', 2),
#  ('sufficiently', 3),
#  ('sufficient', 20),
#  ('sufficiency', 1),
#  ('suffice', 1),
#  ...]

# %%
search_term = "the"

# %%
print(words[search_term])
# Out:
# 4069
